# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

# %%
import torch
from torch import nn, optim
from jcopdl.callback import Callback, set_config

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cpu')

# %% [markdown]
# # Import Dataset

# %%
df = pd.read_csv("data/daily_min_temp.csv", parse_dates=["Date"], index_col="Date")
df.head()
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8

# %%
df.Temp.plot(figsize=(15, 5), color="b")
# Out:
# <AxesSubplot: xlabel='Date'>

# %% [markdown]
# # Dataset Splitting

# %%
ts_train, ts_test = train_test_split(df, test_size=0.2, random_state=42, shuffle=False)
ts_train.shape, ts_test.shape
# Out:
# ((2920, 1), (730, 1))

# %% [markdown]
# # Dataset & Dataloader

# %%
from torch.utils.data import TensorDataset, DataLoader
from jcopdl.utils.dataloader import TimeSeriesDataset

# %%
seq_len = 14
bs = 32

train_set = TimeSeriesDataset(ts_train, "Temp", seq_len)
trainloader = DataLoader(train_set, batch_size=bs, num_workers=4)

test_set = TimeSeriesDataset(ts_test, "Temp", seq_len)
testloader = DataLoader(test_set, batch_size=bs, shuffle=False)
# Out:
# (N, S, F): (208, 14, 1)
# Note: last 7 data excluded
#
# (N, S, F): (52, 14, 1)
# Note: last 1 data excluded

# %% [markdown]
# # Arsitektur & Config

# %%
from jcopdl.layers import linear_block

# %%
class LSTM(nn.Module):
    def __init__(self, input_size, output_size, hidden_size, num_layers, dropout) :
        super().__init__()
        self.rnn = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout)
        self.fc = nn.Linear(hidden_size, output_size)
        
    def forward(self, x, hidden):
        x, hidden = self.rnn(x, hidden)
        x = self.fc(x)
        return x, hidden

# %%
config = set_config({
    "input_size" : train_set.n_feature, 
    "seq_len" :  train_set.n_seq,    
    "output_size" : 1,
    "hidden_size" : 64,
    "num_layers" : 2,
    "dropout" : 0,
})

# %% [markdown]
# # Training Preparation -> MCOC

# %%
model = LSTM(config.input_size, config.output_size, config.hidden_size, config.num_layers, config.dropout).to(device)
criterion = nn.MSELoss(reduction="mean")
optimizer = optim.AdamW(model.parameters(), lr=0.001)
callback = Callback(model, config, outdir="model/lstm")

# %% [markdown]
# # Training

# %%
from tqdm.auto import tqdm

def loop_fn(mode, dataset, dataloader, model, criterion, optimizer, device):
    if mode == "train":
        model.train()
    elif mode == "test":
        model.eval()
    cost = 0
    for feature, target in tqdm(dataloader, desc=mode.title()):
        feature, target = feature.to(device), target.to(device)
        output, hidden = model(feature, None)
        loss = criterion(output, target)

        if mode == "train":
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()

        cost += loss.item() * feature.shape[0]
    cost = cost / len(dataset)
    return cost

# %%
while True:
    train_cost = loop_fn("train", train_set, trainloader, model, criterion, optimizer, device)
    with torch.no_grad():
        test_cost = loop_fn("test", test_set, testloader, model, criterion, optimizer, device)

    # Logging
    callback.log(train_cost, test_cost)

    # Checkpoint
    callback.save_checkpoint()

    # Runtime Plotting
    callback.cost_runtime_plotting()
        
    # Early Stopping
    if callback.early_stopping(model, monitor="test_cost"):
        callback.plot_cost()
        break
# Out:
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch     1
# Train_cost  = 138.0098 | Test_cost  = 140.6368 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch     2
# Train_cost  = 127.1167 | Test_cost  = 125.1392 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch     3
# Train_cost  = 109.6586 | Test_cost  = 104.9916 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch     4
# Train_cost  = 90.6334 | Test_cost  = 86.7761 |
# Train:   0%|          | 0/7 [01:20<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch     5
# Train_cost  = 74.6771 | Test_cost  = 72.7207 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch     6
# Train_cost  = 62.7737 | Test_cost  = 62.2144 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch     7
# Train_cost  = 53.7051 | Test_cost  = 53.8252 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch     8
# Train_cost  = 46.4945 | Test_cost  = 47.1164 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch     9
# Train_cost  = 40.7204 | Test_cost  = 41.6037 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    10
# Train_cost  = 35.9830 | Test_cost  = 37.0506 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    11
# Train_cost  = 32.1441 | Test_cost  = 33.3641 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    12
# Train_cost  = 29.0518 | Test_cost  = 30.3275 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    13
# Train_cost  = 26.5277 | Test_cost  = 27.8239 |
# Train:   0%|          | 0/7 [02:40<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    14
# Train_cost  = 24.4902 | Test_cost  = 25.8049 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    15
# Train_cost  = 22.8779 | Test_cost  = 24.1841 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    16
# Train_cost  = 21.6063 | Test_cost  = 22.8862 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    17
# Train_cost  = 20.6092 | Test_cost  = 21.8515 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    18
# Train_cost  = 19.8323 | Test_cost  = 21.0295 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    19
# Train_cost  = 19.2304 | Test_cost  = 20.3784 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    20
# Train_cost  = 18.7659 | Test_cost  = 19.8633 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    21
# Train_cost  = 18.4085 | Test_cost  = 19.4558 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    22
# Train_cost  = 18.1335 | Test_cost  = 19.1331 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    23
# Train_cost  = 17.9214 | Test_cost  = 18.8766 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    24
# Train_cost  = 17.7570 | Test_cost  = 18.6718 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    25
# Train_cost  = 17.6285 | Test_cost  = 18.5073 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    26
# Train_cost  = 17.5268 | Test_cost  = 18.3742 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    27
# Train_cost  = 17.4451 | Test_cost  = 18.2654 |
# Train:   0%|          | 0/7 [02:20<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    28
# Train_cost  = 17.3782 | Test_cost  = 18.1756 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    29
# Train_cost  = 17.3221 | Test_cost  = 18.0997 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    30
# Train_cost  = 17.2739 | Test_cost  = 18.0365 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    31
# Train_cost  = 17.2334 | Test_cost  = 17.9840 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    32
# Train_cost  = 17.1986 | Test_cost  = 17.9387 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    33
# Train_cost  = 17.1676 | Test_cost  = 17.8994 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    34
# Train_cost  = 17.1400 | Test_cost  = 17.8653 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    35
# Train_cost  = 17.1152 | Test_cost  = 17.8356 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    36
# Train_cost  = 17.0927 | Test_cost  = 17.8095 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    37
# Train_cost  = 17.0722 | Test_cost  = 17.7862 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    38
# Train_cost  = 17.0535 | Test_cost  = 17.7654 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    39
# Train_cost  = 17.0362 | Test_cost  = 17.7466 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    40
# Train_cost  = 17.0201 | Test_cost  = 17.7296 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    41
# Train_cost  = 17.0052 | Test_cost  = 17.7139 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    42
# Train_cost  = 16.9913 | Test_cost  = 17.6994 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    43
# Train_cost  = 16.9780 | Test_cost  = 17.6857 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    44
# Train_cost  = 16.9651 | Test_cost  = 17.6724 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    45
# Train_cost  = 16.9526 | Test_cost  = 17.6601 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    46
# Train_cost  = 16.9411 | Test_cost  = 17.6491 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    47
# Train_cost  = 16.9308 | Test_cost  = 17.6389 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    48
# Train_cost  = 16.9211 | Test_cost  = 17.6293 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    49
# Train_cost  = 16.9119 | Test_cost  = 17.6200 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    50
# Train_cost  = 16.9031 | Test_cost  = 17.6113 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    51
# Train_cost  = 16.8948 | Test_cost  = 17.6031 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    52
# Train_cost  = 16.8869 | Test_cost  = 17.5953 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    53
# Train_cost  = 16.8793 | Test_cost  = 17.5880 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    54
# Train_cost  = 16.8721 | Test_cost  = 17.5810 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    55
# Train_cost  = 16.8652 | Test_cost  = 17.5743 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    56
# Train_cost  = 16.8584 | Test_cost  = 17.5679 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    57
# Train_cost  = 16.8519 | Test_cost  = 17.5618 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    58
# Train_cost  = 16.8455 | Test_cost  = 17.5557 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    59
# Train_cost  = 16.8391 | Test_cost  = 17.5498 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    60
# Train_cost  = 16.8327 | Test_cost  = 17.5439 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    61
# Train_cost  = 16.8260 | Test_cost  = 17.5372 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    62
# Train_cost  = 16.8157 | Test_cost  = 17.5196 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    63
# Train_cost  = 16.7950 | Test_cost  = 17.5190 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    64
# Train_cost  = 16.7867 | Test_cost  = 17.4981 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    65
# Train_cost  = 16.7531 | Test_cost  = 17.4456 |
# Train:   0%|          | 0/7 [01:40<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    66
# Train_cost  = 16.7037 | Test_cost  = 17.3995 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    67
# Train_cost  = 16.6521 | Test_cost  = 17.3456 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    68
# Train_cost  = 16.5918 | Test_cost  = 17.2537 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    69
# Train_cost  = 16.5089 | Test_cost  = 17.1483 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    70
# Train_cost  = 16.4291 | Test_cost  = 17.0603 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    71
# Train_cost  = 16.3353 | Test_cost  = 16.9174 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    72
# Train_cost  = 16.1558 | Test_cost  = 16.6442 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    73
# Train_cost  = 15.8474 | Test_cost  = 16.2448 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    74
# Train_cost  = 15.4038 | Test_cost  = 15.6971 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    75
# Train_cost  = 14.7275 | Test_cost  = 14.6270 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    76
# Train_cost  = 13.5211 | Test_cost  = 13.1303 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    77
# Train_cost  = 12.1834 | Test_cost  = 12.4826 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    78
# Train_cost  = 11.5913 | Test_cost  = 11.5843 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    79
# Train_cost  = 11.0602 | Test_cost  = 10.7330 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    80
# Train_cost  = 10.3275 | Test_cost  = 10.1277 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    81
# Train_cost  = 9.8492 | Test_cost  = 9.6888 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    82
# Train_cost  = 9.5083 | Test_cost  = 9.1747 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    83
# Train_cost  = 9.1312 | Test_cost  = 8.7909 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    84
# Train_cost  = 8.8356 | Test_cost  = 8.4822 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    85
# Train_cost  = 8.6081 | Test_cost  = 8.1973 |
# Train:   0%|          | 0/7 [01:40<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    86
# Train_cost  = 8.4022 | Test_cost  = 7.9613 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    87
# Train_cost  = 8.2183 | Test_cost  = 7.7437 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    88
# Train_cost  = 8.0578 | Test_cost  = 7.5597 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    89
# Train_cost  = 7.9213 | Test_cost  = 7.3879 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    90
# Train_cost  = 7.7955 | Test_cost  = 7.2396 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    91
# Train_cost  = 7.6836 | Test_cost  = 7.1070 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    92
# Train_cost  = 7.5838 | Test_cost  = 6.9935 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    93
# Train_cost  = 7.4975 | Test_cost  = 6.8918 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    94
# Train_cost  = 7.4199 | Test_cost  = 6.8014 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    95
# Train_cost  = 7.3503 | Test_cost  = 6.7195 |
# Train:   0%|          | 0/7 [03:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    96
# Train_cost  = 7.2872 | Test_cost  = 6.6459 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    97
# Train_cost  = 7.2307 | Test_cost  = 6.5781 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    98
# Train_cost  = 7.1793 | Test_cost  = 6.5155 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    99
# Train_cost  = 7.1322 | Test_cost  = 6.4573 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   100
# Train_cost  = 7.0887 | Test_cost  = 6.4036 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   101
# Train_cost  = 7.0485 | Test_cost  = 6.3534 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   102
# Train_cost  = 7.0113 | Test_cost  = 6.3063 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   103
# Train_cost  = 6.9767 | Test_cost  = 6.2621 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   104
# Train_cost  = 6.9443 | Test_cost  = 6.2204 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   105
# Train_cost  = 6.9140 | Test_cost  = 6.1811 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   106
# Train_cost  = 6.8854 | Test_cost  = 6.1442 |
# Train:   0%|          | 0/7 [02:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   107
# Train_cost  = 6.8585 | Test_cost  = 6.1095 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   108
# Train_cost  = 6.8331 | Test_cost  = 6.0769 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   109
# Train_cost  = 6.8091 | Test_cost  = 6.0460 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   110
# Train_cost  = 6.7862 | Test_cost  = 6.0164 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   111
# Train_cost  = 6.7644 | Test_cost  = 5.9881 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   112
# Train_cost  = 6.7435 | Test_cost  = 5.9610 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   113
# Train_cost  = 6.7234 | Test_cost  = 5.9350 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   114
# Train_cost  = 6.7041 | Test_cost  = 5.9102 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   115
# Train_cost  = 6.6854 | Test_cost  = 5.8865 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   116
# Train_cost  = 6.6673 | Test_cost  = 5.8636 |
# Train:   0%|          | 0/7 [03:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   117
# Train_cost  = 6.6498 | Test_cost  = 5.8416 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   118
# Train_cost  = 6.6328 | Test_cost  = 5.8203 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   119
# Train_cost  = 6.6163 | Test_cost  = 5.7997 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   120
# Train_cost  = 6.6002 | Test_cost  = 5.7797 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   121
# Train_cost  = 6.5845 | Test_cost  = 5.7604 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   122
# Train_cost  = 6.5692 | Test_cost  = 5.7418 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   123
# Train_cost  = 6.5542 | Test_cost  = 5.7237 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   124
# Train_cost  = 6.5397 | Test_cost  = 5.7062 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   125
# Train_cost  = 6.5255 | Test_cost  = 5.6894 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   126
# Train_cost  = 6.5118 | Test_cost  = 5.6732 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   127
# Train_cost  = 6.4984 | Test_cost  = 5.6578 |
# Train:   0%|          | 0/7 [02:20<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   128
# Train_cost  = 6.4855 | Test_cost  = 5.6429 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   129
# Train_cost  = 6.4730 | Test_cost  = 5.6286 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   130
# Train_cost  = 6.4609 | Test_cost  = 5.6148 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   131
# Train_cost  = 6.4491 | Test_cost  = 5.6013 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   132
# Train_cost  = 6.4375 | Test_cost  = 5.5880 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   133
# Train_cost  = 6.4262 | Test_cost  = 5.5748 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   134
# Train_cost  = 6.4150 | Test_cost  = 5.5616 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   135
# Train_cost  = 6.4041 | Test_cost  = 5.5486 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   136
# Train_cost  = 6.3933 | Test_cost  = 5.5357 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   137
# Train_cost  = 6.3828 | Test_cost  = 5.5231 |
# Train:   0%|          | 0/7 [03:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   138
# Train_cost  = 6.3725 | Test_cost  = 5.5107 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   139
# Train_cost  = 6.3626 | Test_cost  = 5.4986 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   140
# Train_cost  = 6.3529 | Test_cost  = 5.4868 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   141
# Train_cost  = 6.3434 | Test_cost  = 5.4752 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   142
# Train_cost  = 6.3342 | Test_cost  = 5.4640 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   143
# Train_cost  = 6.3252 | Test_cost  = 5.4530 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   144
# Train_cost  = 6.3164 | Test_cost  = 5.4422 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   145
# Train_cost  = 6.3078 | Test_cost  = 5.4316 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   146
# Train_cost  = 6.2994 | Test_cost  = 5.4212 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   147
# Train_cost  = 6.2911 | Test_cost  = 5.4109 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   148
# Train_cost  = 6.2829 | Test_cost  = 5.4008 |
# Train:   0%|          | 0/7 [02:40<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   149
# Train_cost  = 6.2748 | Test_cost  = 5.3909 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   150
# Train_cost  = 6.2669 | Test_cost  = 5.3811 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   151
# Train_cost  = 6.2590 | Test_cost  = 5.3715 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   152
# Train_cost  = 6.2513 | Test_cost  = 5.3622 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   153
# Train_cost  = 6.2437 | Test_cost  = 5.3533 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   154
# Train_cost  = 6.2362 | Test_cost  = 5.3448 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   155
# Train_cost  = 6.2288 | Test_cost  = 5.3370 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   156
# Train_cost  = 6.2217 | Test_cost  = 5.3298 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   157
# Train_cost  = 6.2148 | Test_cost  = 5.3235 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   158
# Train_cost  = 6.2081 | Test_cost  = 5.3179 |
# Train:   0%|          | 0/7 [03:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   159
# Train_cost  = 6.2016 | Test_cost  = 5.3130 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   160
# Train_cost  = 6.1955 | Test_cost  = 5.3087 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   161
# Train_cost  = 6.1896 | Test_cost  = 5.3050 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   162
# Train_cost  = 6.1840 | Test_cost  = 5.3019 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   163
# Train_cost  = 6.1788 | Test_cost  = 5.2993 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   164
# Train_cost  = 6.1739 | Test_cost  = 5.2971 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   165
# Train_cost  = 6.1694 | Test_cost  = 5.2953 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   166
# Train_cost  = 6.1652 | Test_cost  = 5.2933 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   167
# Train_cost  = 6.1613 | Test_cost  = 5.2907 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   168
# Train_cost  = 6.1574 | Test_cost  = 5.2868 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   169
# Train_cost  = 6.1533 | Test_cost  = 5.2808 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   170
# Train_cost  = 6.1486 | Test_cost  = 5.2729 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   171
# Train_cost  = 6.1431 | Test_cost  = 5.2639 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   172
# Train_cost  = 6.1369 | Test_cost  = 5.2553 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   173
# Train_cost  = 6.1306 | Test_cost  = 5.2481 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   174
# Train_cost  = 6.1248 | Test_cost  = 5.2430 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   175
# Train_cost  = 6.1201 | Test_cost  = 5.2403 |
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   176
# Train_cost  = 6.1167 | Test_cost  = 5.2407 |
# ==> EarlyStop patience =  1 | Best test_cost: 5.2403
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   177
# Train_cost  = 6.1148 | Test_cost  = 5.2456 |
# ==> EarlyStop patience =  2 | Best test_cost: 5.2403
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   178
# Train_cost  = 6.1145 | Test_cost  = 5.2577 |
# ==> EarlyStop patience =  3 | Best test_cost: 5.2403
# Train:   0%|          | 0/7 [03:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   179
# Train_cost  = 6.1164 | Test_cost  = 5.2804 |
# ==> EarlyStop patience =  4 | Best test_cost: 5.2403
# Train:   0%|          | 0/7 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   180
# Train_cost  = 6.1203 | Test_cost  = 5.3119 |
# ==> EarlyStop patience =  5 | Best test_cost: 5.2403
# ==> Execute Early Stopping at epoch: 180 | Best test_cost: 5.2403
# ==> Best model is saved at model/lstm

# %% [markdown]
# # Forecast

# %%
from luwiji.rnn import illustration

# %%
illustration.forecast

# %%
from utils import data4pred, pred4pred

# %%
train_forecast_set = TimeSeriesDataset(ts_train, "Temp", 1)
trainforecastloader = DataLoader(train_forecast_set)

test_forecast_set = TimeSeriesDataset(ts_test, "Temp", 1)
testforecastloader = DataLoader(test_forecast_set)
# Out:
# (N, S, F): (2919, 1, 1)
# Note: last 0 data excluded
#
# (N, S, F): (729, 1, 1)
# Note: last 0 data excluded

# %%
plt.figure(figsize=(15, 10))

plt.subplot(211)
data4pred(model, train_forecast_set, trainforecastloader, device)
plt.title("Train")

plt.subplot(212)
data4pred(model, test_forecast_set, testforecastloader, device)
plt.title("Test")
# Out:
# Text(0.5, 1.0, 'Test')

# %%
plt.figure(figsize=(15, 5))
pred4pred(model, test_forecast_set, testforecastloader, device)
plt.title("Test");
